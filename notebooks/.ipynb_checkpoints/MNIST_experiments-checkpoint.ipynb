# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.datasets.mnist_loader import mnist_loader
from src.datasets.cifar_loader import cifar_loader
from src.train import train_SimpleCNN
from src.evaluate import evaluate_SimpleCNN_test

# %%
BATCH_SIZE = 32

train_SimpleCNN(num_epochs=8, batch_size=BATCH_SIZE, optimization='sgd', learning_rate=0.005, dataset='mnist')
# Out:
# Epoch [1/8], Loss: 1.1851
# Epoch [2/8], Loss: 0.3280
# Epoch [3/8], Loss: 0.2381
# Epoch [4/8], Loss: 0.1761
# Epoch [5/8], Loss: 0.1377
# Epoch [6/8], Loss: 0.1136
# Epoch [7/8], Loss: 0.0975
# Epoch [8/8], Loss: 0.0857

# %%
evaluate_SimpleCNN_test(batch_size=BATCH_SIZE, dataset='mnist')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 evaluate_SimpleCNN_test(batch_size=BATCH_SIZE, dataset='mnist')
#
# File ~/Documents/Data_projects/optimization-dynamics/src/evaluate.py:10, in evaluate_SimpleCNN_test(dataset, batch_size)
#       7 def evaluate_SimpleCNN_test(dataset='mnist', batch_size=32):
#       9     if dataset != 'mnist' or dataset != 'cifar':
# ---> 10         raise ValueError('Invalid dataset for evaluating the model on test set')
#      12     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      14     if dataset == 'mnist':
#
# ValueError: Invalid dataset for evaluating the model on test set
