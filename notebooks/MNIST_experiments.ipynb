# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.datasets.mnist_loader import mnist_loader
from src.datasets.cifar_loader import cifar_loader
from src.train import train_SimpleCNN
from src.evaluate import evaluate_SimpleCNN_test

# %%
BATCH_SIZE = 32

train_SimpleCNN(num_epochs=10, batch_size=BATCH_SIZE, optimization='sgd', learning_rate=0.001, dataset='cifar')
# Out:
# 100%|████████████████████████████████████████| 170M/170M [00:15<00:00, 11.3MB/s]
# /home/amir/Documents/Data_projects/optimization-dynamics/venv/lib64/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 BATCH_SIZE = 32
# ----> 3 train_SimpleCNN(num_epochs=10, batch_size=BATCH_SIZE, optimization='sgd', learning_rate=0.001, dataset='cifar')
#
# File ~/Documents/Data_projects/optimization-dynamics/src/train.py:49, in train_SimpleCNN(num_epochs, batch_size, optimization, learning_rate, dataset)
#      47 for images, labels in train_loader:
# ...

# %%
evaluate_mnist(batch_size=BATCH_SIZE, dataset='cifar')
# Out:
# Test accuracy = 93.38%
